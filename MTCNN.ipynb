# %% [markdown]
# <a href="https://colab.research.google.com/github/HoanDiep/BT11_tuan12/blob/main/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 40.4 MB/s eta 0:00:00
# ...

# %%
from mtcnn import MTCNN

# %%
import matplotlib.pyplot as plt

# %%
filename = 'nhiung.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# ...
# 8/8 [==============================] - 0s 41ms/step
# {'box': [329, 269, 45, 60], 'confidence': 0.9999956488609314, 'keypoints': {'left_eye': (341, 292), 'right_eye': (361, 293), 'nose': (351, 308), 'mouth_left': (341, 312), 'mouth_right': (362, 313)}}
# {'box': [251, 249, 29, 33], 'confidence': 0.9999948143959045, 'keypoints': {'left_eye': (263, 258), 'right_eye': (276, 259), 'nose': (272, 265), 'mouth_left': (263, 274), 'mouth_right': (275, 274)}}
# {'box': [525, 220, 14, 17], 'confidence': 0.999993622303009, 'keypoints': {'left_eye': (529, 225), 'right_eye': (537, 226), 'nose': (533, 229), 'mouth_left': (529, 232), 'mouth_right': (535, 233)}}
# {'box': [508, 246, 16, 20], 'confidence': 0.9999895691871643, 'keypoints': {'left_eye': (512, 253), 'right_eye': (520, 253), 'nose': (516, 257), 'mouth_left': (513, 261), 'mouth_right': (519, 261)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

filename = 'abc.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax=plt.gca()
i=0
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height,fill=False,color = 'red')
  ax.add_patch(rect)
  i+=1
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value,radius=2,color ='red')
    ax.add_patch(dot)
plt.savefig('detected.jpg')
plt.show()
print(i)
# Out:
# ...
# 24/24 [==============================] - 1s 54ms/step
# 135

# %%
from google.colab import drive
drive.mount('/content/drive')

import matplotlib.pyplot as plt
from mtcnn  import MTCNN

def draw_faces(filename,result_list):
  data=plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2=x1+width,y1+height
    plt.subplot(1,len(result_list),i+1)

    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
    t = 'face'+str(i)+'.jpg'
    plt.savefig(t)
    #!cp t "/content/drive/My Drive/Colab Notebooks/face"
  plt.show()
filename = 'giadinh.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces=detector.detect_faces(img)
draw_faces(filename,faces)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# 1/1 [==============================] - 0s 283ms/step
